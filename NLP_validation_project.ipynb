# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import pandas as pd
import numpy as np
import re
import string
import warnings
warnings.filterwarnings("ignore")

# NLP Libraries
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Visualization
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Machine Learning Libraries
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Input, Dense, Embedding
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import plot_model

# Save/Load Model
import pickle as pkl

# %%
# Load dataset
df = pd.read_csv("/content/output1433.csv")

# Convert text to lowercase
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].str.lower()

# Remove duplicates
df = df.drop_duplicates().reset_index(drop=True)

# Remove punctuation, digits, and extra spaces
def clean_text(text):
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = text.strip()  # Remove leading/trailing spaces
    return text

df['Question'] = df['Question'].apply(clean_text)
df['Answer'] = df['Answer'].apply(clean_text)

# Add start and end tokens to answers
df['Answer'] = df['Answer'].apply(lambda x: 'start_ ' + x + ' _end')

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['Question'], df['Answer'], test_size=0.3, random_state=101)

# Tokenize input (questions)
tokenizer_input = Tokenizer()
tokenizer_input.fit_on_texts(X_train)
X_train_seq = tokenizer_input.texts_to_sequences(X_train)
X_test_seq = tokenizer_input.texts_to_sequences(X_test)

# Tokenize output (answers)
tokenizer_target = Tokenizer()
tokenizer_target.fit_on_texts(y_train)
y_train_seq = tokenizer_target.texts_to_sequences(y_train)
y_test_seq = tokenizer_target.texts_to_sequences(y_test)

# Pad sequences
max_length_src = max(len(seq) for seq in X_train_seq)
max_length_tar = max(len(seq) for seq in y_train_seq)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_length_src, padding='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=max_length_src, padding='post')
y_train_pad = pad_sequences(y_train_seq, maxlen=max_length_tar, padding='post')
y_test_pad = pad_sequences(y_test_seq, maxlen=max_length_tar, padding='post')

# Vocabulary sizes
vocab_size_input = len(tokenizer_input.word_index) + 1
vocab_size_target = len(tokenizer_target.word_index) + 1

# %%
with open('tokenizer_input.pkl', 'wb') as f:
    pkl.dump(tokenizer_input, f)

with open('tokenizer_target.pkl', 'wb') as f:
    pkl.dump(tokenizer_target, f)


# pkl.dump(tokenizer_input, open('tokenizer_input.pkl', 'wb'))
# pkl.dump(tokenizer_target, open('tokenizer_target.pkl', 'wb'))

# %%
latent_dim = 256  # Embedding dimension

# Encoder
encoder_inputs = Input(shape=(None,),name="encoder_inputs")
encoder_embedding = Embedding(vocab_size_input, latent_dim, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,),name="decoder_inputs")
decoder_embedding = Embedding(vocab_size_target, latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size_target, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, None, 256) │     49,920 │ encoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_9         │ (None, None)      │          0 │ encoder_inputs[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, None, 256) │     60,672 │ decoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 256),     │    525,312 │ embedding_2[0][0… │
# │                     │ (None, 256),      │            │ not_equal_9[0][0] │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    525,312 │ embedding_3[0][0… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 237) │     60,909 │ lstm_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,222,125 (4.66 MB)
#  Trainable params: 1,222,125 (4.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ==========================================================================================================================================================

# %%
def generator_batch(X, Y, batch_size=20):
    while True:
        for j in range(0, len(X), batch_size):
            encoder_input = X[j:j+batch_size]
            decoder_input = Y[j:j+batch_size][:, :-1]  # Remove 'end' token
            decoder_output = np.zeros((len(decoder_input), max_length_tar-1, vocab_size_target))  # Adjust shape

            for i, seq in enumerate(Y[j:j+batch_size]):
                for t, word in enumerate(seq[1:]):  # Shift by one for teacher forcing
                    if t < max_length_tar - 1:  # Ensure indexing within bounds
                        decoder_output[i, t, word] = 1

            yield ((encoder_input, decoder_input), decoder_output)


# Train the model
batch_size = 32
epochs = 200
history = model.fit(
    generator_batch(X_train_pad, y_train_pad, batch_size=batch_size),
    steps_per_epoch=len(X_train_pad) // batch_size,
    epochs=epochs,
    validation_data=generator_batch(X_test_pad, y_test_pad, batch_size=batch_size),
    validation_steps=len(X_test_pad) // batch_size
)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.2753 - loss: 5.4555 - val_accuracy: 0.6499 - val_loss: 5.4101
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 743ms/step - accuracy: 0.5975 - loss: 5.3868 - val_accuracy: 0.6342 - val_loss: 5.1656
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 691ms/step - accuracy: 0.5786 - loss: 4.9170 - val_accuracy: 0.6349 - val_loss: 4.3335
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 715ms/step - accuracy: 0.5889 - loss: 4.3592 - val_accuracy: 0.5334 - val_loss: 4.2518
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.5863 - loss: 4.2341 - val_accuracy: 0.6506 - val_loss: 4.1010
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 676ms/step - accuracy: 0.6138 - loss: 4.1265 - val_accuracy: 0.0469 - val_loss: 4.1214
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2912 - loss: 4.1566 - val_accuracy: 0.6570 - val_loss: 3.9261
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.6361 - loss: 4.0309 - val_accuracy: 0.6541 - val_loss: 3.8499
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.5048 - loss: 3.9039 - val_accuracy: 0.6875 - val_loss: 3.7897
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.6499 - loss: 3.7592 - val_accuracy: 0.6548 - val_loss: 3.7010
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.5703 - loss: 3.7270 - val_accuracy: 0.1186 - val_loss: 3.7238
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.1639 - loss: 3.7056 - val_accuracy: 0.1875 - val_loss: 3.5902
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2140 - loss: 3.6828 - val_accuracy: 0.1364 - val_loss: 3.5638
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.2592 - loss: 3.5562 - val_accuracy: 0.1626 - val_loss: 3.5067
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.1722 - loss: 3.4910 - val_accuracy: 0.1591 - val_loss: 3.4336
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step - accuracy: 0.1685 - loss: 3.4177 - val_accuracy: 0.1626 - val_loss: 3.4154
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 0.1578 - loss: 3.4549 - val_accuracy: 0.1428 - val_loss: 3.4071
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - accuracy: 0.1553 - loss: 3.4729 - val_accuracy: 0.1712 - val_loss: 3.4564
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.1756 - loss: 3.3796 - val_accuracy: 0.1520 - val_loss: 3.3065
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.1589 - loss: 3.2045 - val_accuracy: 0.1463 - val_loss: 3.2934
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.1562 - loss: 3.2205 - val_accuracy: 0.1626 - val_loss: 3.2518
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.1546 - loss: 3.2570 - val_accuracy: 0.1761 - val_loss: 3.2412
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.1755 - loss: 3.2356 - val_accuracy: 0.1612 - val_loss: 3.1437
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.1644 - loss: 3.0871 - val_accuracy: 0.1577 - val_loss: 3.1581
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.1693 - loss: 3.0442 - val_accuracy: 0.1598 - val_loss: 3.0639
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.1543 - loss: 3.0192 - val_accuracy: 0.1811 - val_loss: 3.0460
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.1722 - loss: 2.9919 - val_accuracy: 0.1463 - val_loss: 3.0131
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.1568 - loss: 3.0383 - val_accuracy: 0.1655 - val_loss: 3.0538
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 733ms/step - accuracy: 0.1741 - loss: 2.9231 - val_accuracy: 0.1555 - val_loss: 2.9196
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.1675 - loss: 2.8014 - val_accuracy: 0.1733 - val_loss: 2.8810
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.1634 - loss: 2.7874 - val_accuracy: 0.1797 - val_loss: 2.8914
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.1813 - loss: 2.8007 - val_accuracy: 0.1669 - val_loss: 2.9561
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.1738 - loss: 2.8788 - val_accuracy: 0.1712 - val_loss: 2.7992
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.1909 - loss: 2.6378 - val_accuracy: 0.1584 - val_loss: 2.7770
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.1829 - loss: 2.5792 - val_accuracy: 0.1783 - val_loss: 2.7442
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.1898 - loss: 2.5745 - val_accuracy: 0.1754 - val_loss: 2.6701
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.1920 - loss: 2.5421 - val_accuracy: 0.1847 - val_loss: 2.6775
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.1980 - loss: 2.6171 - val_accuracy: 0.1946 - val_loss: 2.6237
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2138 - loss: 2.4042 - val_accuracy: 0.1832 - val_loss: 2.6106
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.2116 - loss: 2.3535 - val_accuracy: 0.2024 - val_loss: 2.5417
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 727ms/step - accuracy: 0.2155 - loss: 2.3064 - val_accuracy: 0.1967 - val_loss: 2.4966
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.2139 - loss: 2.3248 - val_accuracy: 0.2010 - val_loss: 2.4879
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.2186 - loss: 2.3508 - val_accuracy: 0.2067 - val_loss: 2.4213
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.2338 - loss: 2.1795 - val_accuracy: 0.1939 - val_loss: 2.4537
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.2304 - loss: 2.1330 - val_accuracy: 0.2237 - val_loss: 2.3682
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.2350 - loss: 2.1168 - val_accuracy: 0.2230 - val_loss: 2.3271
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.2356 - loss: 2.0983 - val_accuracy: 0.2273 - val_loss: 2.3110
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2450 - loss: 2.1239 - val_accuracy: 0.2131 - val_loss: 2.3295
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.2625 - loss: 1.9748 - val_accuracy: 0.2209 - val_loss: 2.2626
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.2662 - loss: 1.8919 - val_accuracy: 0.2280 - val_loss: 2.2301
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 369ms/step - accuracy: 0.2634 - loss: 1.8388 - val_accuracy: 0.2372 - val_loss: 2.1926
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step - accuracy: 0.2623 - loss: 1.8585 - val_accuracy: 0.2287 - val_loss: 2.2278
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.2550 - loss: 1.9426 - val_accuracy: 0.2344 - val_loss: 2.1667
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.2780 - loss: 1.7619 - val_accuracy: 0.2259 - val_loss: 2.1707
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.2727 - loss: 1.7184 - val_accuracy: 0.2308 - val_loss: 2.1756
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.2859 - loss: 1.6448 - val_accuracy: 0.2422 - val_loss: 2.0920
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.2814 - loss: 1.6757 - val_accuracy: 0.2443 - val_loss: 2.0860
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.2811 - loss: 1.7002 - val_accuracy: 0.2401 - val_loss: 2.0675
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.2899 - loss: 1.5718 - val_accuracy: 0.2386 - val_loss: 2.1097
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.3000 - loss: 1.5092 - val_accuracy: 0.2408 - val_loss: 2.0608
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step - accuracy: 0.2972 - loss: 1.4798 - val_accuracy: 0.2472 - val_loss: 2.0276
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 745ms/step - accuracy: 0.2962 - loss: 1.5040 - val_accuracy: 0.2464 - val_loss: 2.0087
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.2916 - loss: 1.5258 - val_accuracy: 0.2528 - val_loss: 1.9740
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.3077 - loss: 1.3869 - val_accuracy: 0.2436 - val_loss: 1.9845
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.3106 - loss: 1.3235 - val_accuracy: 0.2472 - val_loss: 1.9980
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.3063 - loss: 1.3593 - val_accuracy: 0.2550 - val_loss: 1.9353
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 430ms/step - accuracy: 0.3088 - loss: 1.3314 - val_accuracy: 0.2521 - val_loss: 1.9165
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.2998 - loss: 1.3912 - val_accuracy: 0.2528 - val_loss: 1.9112
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.3190 - loss: 1.2551 - val_accuracy: 0.2507 - val_loss: 1.8890
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.3276 - loss: 1.1548 - val_accuracy: 0.2578 - val_loss: 1.8900
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.3211 - loss: 1.1786 - val_accuracy: 0.2642 - val_loss: 1.8781
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step - accuracy: 0.3247 - loss: 1.1710 - val_accuracy: 0.2585 - val_loss: 1.8640
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.3163 - loss: 1.2516 - val_accuracy: 0.2614 - val_loss: 1.8476
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 0.3332 - loss: 1.0983 - val_accuracy: 0.2571 - val_loss: 1.8554
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.3396 - loss: 1.0365 - val_accuracy: 0.2592 - val_loss: 1.8711
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.3377 - loss: 1.0429 - val_accuracy: 0.2599 - val_loss: 1.8721
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.3330 - loss: 1.0575 - val_accuracy: 0.2642 - val_loss: 1.8350
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.3339 - loss: 1.0782 - val_accuracy: 0.2663 - val_loss: 1.8197
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.3469 - loss: 1.0054 - val_accuracy: 0.2663 - val_loss: 1.8157
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.3533 - loss: 0.9164 - val_accuracy: 0.2713 - val_loss: 1.8033
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.3605 - loss: 0.8902 - val_accuracy: 0.2727 - val_loss: 1.7927
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.3574 - loss: 0.9159 - val_accuracy: 0.2699 - val_loss: 1.8073
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 0.3507 - loss: 0.9489 - val_accuracy: 0.2713 - val_loss: 1.7925
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - accuracy: 0.3597 - loss: 0.9014 - val_accuracy: 0.2699 - val_loss: 1.7617
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.3728 - loss: 0.7962 - val_accuracy: 0.2699 - val_loss: 1.7896
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.3673 - loss: 0.8204 - val_accuracy: 0.2699 - val_loss: 1.7871
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.3727 - loss: 0.7969 - val_accuracy: 0.2656 - val_loss: 1.7953
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.3642 - loss: 0.8650 - val_accuracy: 0.2749 - val_loss: 1.7646
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.3722 - loss: 0.7759 - val_accuracy: 0.2678 - val_loss: 1.7895
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.3876 - loss: 0.7330 - val_accuracy: 0.2734 - val_loss: 1.7548
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.3855 - loss: 0.7036 - val_accuracy: 0.2777 - val_loss: 1.7442
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.3924 - loss: 0.6902 - val_accuracy: 0.2749 - val_loss: 1.7682
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.3783 - loss: 0.7766 - val_accuracy: 0.2749 - val_loss: 1.7320
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.3829 - loss: 0.6899 - val_accuracy: 0.2777 - val_loss: 1.7313
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.3935 - loss: 0.6349 - val_accuracy: 0.2741 - val_loss: 1.7555
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.3952 - loss: 0.6204 - val_accuracy: 0.2777 - val_loss: 1.7250
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.3974 - loss: 0.6019 - val_accuracy: 0.2770 - val_loss: 1.7468
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.3954 - loss: 0.6380 - val_accuracy: 0.2784 - val_loss: 1.7286
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.3924 - loss: 0.6176 - val_accuracy: 0.2734 - val_loss: 1.7600
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.3989 - loss: 0.5790 - val_accuracy: 0.2791 - val_loss: 1.7213
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.4000 - loss: 0.5483 - val_accuracy: 0.2798 - val_loss: 1.7218
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.4089 - loss: 0.5322 - val_accuracy: 0.2770 - val_loss: 1.7359
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.4114 - loss: 0.5614 - val_accuracy: 0.2827 - val_loss: 1.7048
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.3993 - loss: 0.5483 - val_accuracy: 0.2749 - val_loss: 1.7237
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step - accuracy: 0.4133 - loss: 0.4917 - val_accuracy: 0.2805 - val_loss: 1.7469
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 732ms/step - accuracy: 0.4077 - loss: 0.4928 - val_accuracy: 0.2812 - val_loss: 1.7508
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.4129 - loss: 0.4884 - val_accuracy: 0.2791 - val_loss: 1.7339
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4153 - loss: 0.4948 - val_accuracy: 0.2827 - val_loss: 1.7129
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.4163 - loss: 0.4605 - val_accuracy: 0.2798 - val_loss: 1.7260
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.4206 - loss: 0.4422 - val_accuracy: 0.2820 - val_loss: 1.7220
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.4129 - loss: 0.4331 - val_accuracy: 0.2812 - val_loss: 1.7305
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.4190 - loss: 0.4136 - val_accuracy: 0.2791 - val_loss: 1.7404
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.4213 - loss: 0.4387 - val_accuracy: 0.2820 - val_loss: 1.7074
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4131 - loss: 0.4423 - val_accuracy: 0.2791 - val_loss: 1.7417
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.4230 - loss: 0.3992 - val_accuracy: 0.2848 - val_loss: 1.7317
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 377ms/step - accuracy: 0.4184 - loss: 0.3848 - val_accuracy: 0.2812 - val_loss: 1.7408
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 311ms/step - accuracy: 0.4217 - loss: 0.3680 - val_accuracy: 0.2820 - val_loss: 1.7227
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.4250 - loss: 0.3772 - val_accuracy: 0.2848 - val_loss: 1.7173
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.4275 - loss: 0.3567 - val_accuracy: 0.2791 - val_loss: 1.7186
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.4271 - loss: 0.3503 - val_accuracy: 0.2827 - val_loss: 1.7357
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.4236 - loss: 0.3408 - val_accuracy: 0.2777 - val_loss: 1.7703
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.4201 - loss: 0.3571 - val_accuracy: 0.2820 - val_loss: 1.7564
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.4260 - loss: 0.3541 - val_accuracy: 0.2834 - val_loss: 1.7216
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4291 - loss: 0.3230 - val_accuracy: 0.2791 - val_loss: 1.7436
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.4299 - loss: 0.3125 - val_accuracy: 0.2812 - val_loss: 1.7651
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4261 - loss: 0.3054 - val_accuracy: 0.2812 - val_loss: 1.7562
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.4244 - loss: 0.2960 - val_accuracy: 0.2820 - val_loss: 1.7526
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - accuracy: 0.4269 - loss: 0.3247 - val_accuracy: 0.2827 - val_loss: 1.7431
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - accuracy: 0.4295 - loss: 0.2944 - val_accuracy: 0.2820 - val_loss: 1.7503
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.4302 - loss: 0.2776 - val_accuracy: 0.2827 - val_loss: 1.7592
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.4298 - loss: 0.2671 - val_accuracy: 0.2805 - val_loss: 1.7601
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.4316 - loss: 0.2574 - val_accuracy: 0.2805 - val_loss: 1.7671
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4323 - loss: 0.2749 - val_accuracy: 0.2820 - val_loss: 1.7521
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.4340 - loss: 0.2763 - val_accuracy: 0.2777 - val_loss: 1.7680
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.4335 - loss: 0.2555 - val_accuracy: 0.2812 - val_loss: 1.7537
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.4295 - loss: 0.2561 - val_accuracy: 0.2791 - val_loss: 1.7805
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.4290 - loss: 0.2580 - val_accuracy: 0.2820 - val_loss: 1.7682
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.4328 - loss: 0.2624 - val_accuracy: 0.2827 - val_loss: 1.7689
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - accuracy: 0.4375 - loss: 0.2336 - val_accuracy: 0.2784 - val_loss: 1.7723
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 732ms/step - accuracy: 0.4347 - loss: 0.2316 - val_accuracy: 0.2820 - val_loss: 1.7735
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.4346 - loss: 0.2184 - val_accuracy: 0.2827 - val_loss: 1.7854
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.4361 - loss: 0.2081 - val_accuracy: 0.2805 - val_loss: 1.7909
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.4390 - loss: 0.2217 - val_accuracy: 0.2791 - val_loss: 1.7997
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.4393 - loss: 0.2152 - val_accuracy: 0.2812 - val_loss: 1.8111
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.4339 - loss: 0.2425 - val_accuracy: 0.2805 - val_loss: 1.8103
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - accuracy: 0.4334 - loss: 0.2233 - val_accuracy: 0.2827 - val_loss: 1.8084
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.4349 - loss: 0.2156 - val_accuracy: 0.2820 - val_loss: 1.8172
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4393 - loss: 0.2119 - val_accuracy: 0.2812 - val_loss: 1.7946
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 0.4398 - loss: 0.1967 - val_accuracy: 0.2798 - val_loss: 1.8019
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 721ms/step - accuracy: 0.4381 - loss: 0.1975 - val_accuracy: 0.2834 - val_loss: 1.7983
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.4370 - loss: 0.1874 - val_accuracy: 0.2820 - val_loss: 1.8075
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.4375 - loss: 0.1788 - val_accuracy: 0.2791 - val_loss: 1.8141
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.4407 - loss: 0.1889 - val_accuracy: 0.2798 - val_loss: 1.8168
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.4417 - loss: 0.1839 - val_accuracy: 0.2798 - val_loss: 1.8214
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.4378 - loss: 0.1896 - val_accuracy: 0.2827 - val_loss: 1.8446
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.4367 - loss: 0.1804 - val_accuracy: 0.2834 - val_loss: 1.8566
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.4366 - loss: 0.1713 - val_accuracy: 0.2784 - val_loss: 1.8540
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.4417 - loss: 0.1793 - val_accuracy: 0.2784 - val_loss: 1.8406
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.4391 - loss: 0.1755 - val_accuracy: 0.2777 - val_loss: 1.8865
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 732ms/step - accuracy: 0.4326 - loss: 0.2260 - val_accuracy: 0.2791 - val_loss: 1.8542
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.4356 - loss: 0.1888 - val_accuracy: 0.2820 - val_loss: 1.8658
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.4381 - loss: 0.1600 - val_accuracy: 0.2784 - val_loss: 1.8502
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.4422 - loss: 0.1661 - val_accuracy: 0.2784 - val_loss: 1.8479
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4410 - loss: 0.1607 - val_accuracy: 0.2791 - val_loss: 1.8554
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.4385 - loss: 0.1657 - val_accuracy: 0.2812 - val_loss: 1.8641
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.4373 - loss: 0.1577 - val_accuracy: 0.2827 - val_loss: 1.8698
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.4378 - loss: 0.1497 - val_accuracy: 0.2777 - val_loss: 1.8649
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.4424 - loss: 0.1572 - val_accuracy: 0.2791 - val_loss: 1.8647
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.4411 - loss: 0.1535 - val_accuracy: 0.2791 - val_loss: 1.8720
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.4385 - loss: 0.1590 - val_accuracy: 0.2827 - val_loss: 1.8850
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 729ms/step - accuracy: 0.4366 - loss: 0.1520 - val_accuracy: 0.2820 - val_loss: 1.8977
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.4380 - loss: 0.1463 - val_accuracy: 0.2756 - val_loss: 1.8925
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 0.4405 - loss: 0.1569 - val_accuracy: 0.2784 - val_loss: 1.8955
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.4414 - loss: 0.1655 - val_accuracy: 0.2812 - val_loss: 1.8885
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.4371 - loss: 0.1581 - val_accuracy: 0.2827 - val_loss: 1.9147
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.4377 - loss: 0.1475 - val_accuracy: 0.2827 - val_loss: 1.9079
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.4382 - loss: 0.1385 - val_accuracy: 0.2756 - val_loss: 1.9044
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.4414 - loss: 0.1439 - val_accuracy: 0.2777 - val_loss: 1.8956
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.4403 - loss: 0.1430 - val_accuracy: 0.2777 - val_loss: 1.9052
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.4385 - loss: 0.1477 - val_accuracy: 0.2812 - val_loss: 1.9199
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - accuracy: 0.4364 - loss: 0.1413 - val_accuracy: 0.2834 - val_loss: 1.9264
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step - accuracy: 0.4378 - loss: 0.1333 - val_accuracy: 0.2763 - val_loss: 1.9219
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4421 - loss: 0.1391 - val_accuracy: 0.2777 - val_loss: 1.9135
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.4400 - loss: 0.1378 - val_accuracy: 0.2777 - val_loss: 1.9281
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.4385 - loss: 0.1448 - val_accuracy: 0.2820 - val_loss: 1.9389
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.4364 - loss: 0.1407 - val_accuracy: 0.2820 - val_loss: 1.9819
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4374 - loss: 0.1326 - val_accuracy: 0.2756 - val_loss: 1.9436
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.4415 - loss: 0.1355 - val_accuracy: 0.2784 - val_loss: 1.9331
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.4395 - loss: 0.1338 - val_accuracy: 0.2763 - val_loss: 1.9444
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.4382 - loss: 0.1392 - val_accuracy: 0.2812 - val_loss: 1.9570
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - accuracy: 0.4357 - loss: 0.1333 - val_accuracy: 0.2805 - val_loss: 1.9555
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 0.4374 - loss: 0.1249 - val_accuracy: 0.2756 - val_loss: 1.9527
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 728ms/step - accuracy: 0.4418 - loss: 0.1307 - val_accuracy: 0.2777 - val_loss: 1.9477
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.4407 - loss: 0.1298 - val_accuracy: 0.2763 - val_loss: 1.9639
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4389 - loss: 0.1359 - val_accuracy: 0.2812 - val_loss: 1.9732
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.4364 - loss: 0.1299 - val_accuracy: 0.2812 - val_loss: 1.9709
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - accuracy: 0.4376 - loss: 0.1218 - val_accuracy: 0.2770 - val_loss: 1.9675
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.4411 - loss: 0.1273 - val_accuracy: 0.2763 - val_loss: 1.9631
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.4401 - loss: 0.1272 - val_accuracy: 0.2763 - val_loss: 1.9748
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.4383 - loss: 0.1331 - val_accuracy: 0.2791 - val_loss: 1.9853

# %%
# Save the model
model_json = model.to_json()
with open("model_qa.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model_qa.weights.h5")
print("Model & Weights Saved to disk")

# Load the model
json_file = open('model_qa.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model_loaded = model_from_json(loaded_model_json)
model_loaded.load_weights("model_qa.weights.h5")
print("Model Loaded from disk")
# Out:
# Model & Weights Saved to disk
# Model Loaded from disk

# %%
latent_dim = 256

#inference encoder
encoder_inputs_inf = model_loaded.input[0] #Trained encoder input layer
encoder_outputs_inf, inf_state_h, inf_state_c = model_loaded.layers[4].output # restoring the encoder lstm output and states
encoder_inf_states = [inf_state_h,inf_state_c]
encoder_model = Model(encoder_inputs_inf,encoder_inf_states)

#inference decoder
# The following tensor will store the state of the previous timestep in the "starting the encoder final time step"
decoder_state_h_input = Input(shape=(latent_dim,))
decoder_state_c_input = Input(shape=(latent_dim,))
decoder_state_input = [decoder_state_h_input,decoder_state_c_input]

# # inference decoder input
decoder_input_inf = model_loaded.input[1] #Trained decoder input layer
# decoder_input_inf._name='decoder_input'
decoder_emb_inf = model_loaded.layers[3](decoder_input_inf)
decoder_lstm_inf = model_loaded.layers[5]
decoder_output_inf, decoder_state_h_inf, decoder_state_c_inf = decoder_lstm_inf(decoder_emb_inf, initial_state =decoder_state_input)
decoder_state_inf = [decoder_state_h_inf,decoder_state_c_inf]
#inference dense layer
dense_inf = model_loaded.layers[6]
decoder_output_final = dense_inf(decoder_output_inf)# A dense softmax layer to generate prob dist. over the target vocabulary

decoder_model = Model([decoder_input_inf]+decoder_state_input,[decoder_output_final]+decoder_state_inf)

# %%
import os

print(os.listdir())  # Lists all files in the current directory
# Out:
# ['.config', 'model_qa.json', 'model_qa.weights.h5', 'tokenizer_input.pkl', 'output1433.csv', 'tokenizer_target.pkl', 'sample_data']

# %%
with open('tokenizer_input.pkl', 'rb') as f:
    tokenizer_input = pkl.load(f)
with open('tokenizer_target.pkl', 'rb') as f:
    tokenizer_target = pkl.load(f)

# Creating the reverse mapping to get the word from the index in the sequence
reverse_word_map_input = dict(map(reversed,
                                  tokenizer_input.word_index.items()))
reverse_word_map_target = dict(
    map(reversed, tokenizer_target.word_index.items()))

# %% [markdown]
# ============================================================

# %%
# Code to answer the input question


def decode_seq(input_seq):
    # print("input_seq=>",input_seq)
    state_values_encoder = encoder_model.predict(input_seq)

    # intialize the target seq with start tag
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = tokenizer_target.word_index['start']
    # print("target_seq:=>",target_seq)
    stop_condition = False
    decoder_sentance = ''
    # print("Before the while loop")
    while not stop_condition:
        sample_word, decoder_h, decoder_c = decoder_model.predict(
            [target_seq] + state_values_encoder)
        # print("sample_word: =>",sample_word)
        sample_word_index = np.argmax(sample_word[0, -1, :])
        # print("sample_word_index: ",sample_word_index)
        decoder_word = reverse_word_map_target[sample_word_index]
        decoder_sentance += ' '\
        + decoder_word
        # print("decoded word:=>",decoder_word)
        # print(len(decoder_sentance))
        # print("len(decoder_sentance) > 70: ",len(decoder_sentance) > 70)
        # print('decoder_word == "end"',decoder_word == 'end')
        # print(decoder_word == 'end' or len(decoder_sentance) > 70)
        # stop condition for the while loop
        if (decoder_word == 'end' or len(decoder_sentance) >
                100):  # Taking upto 100 words as answer
            stop_condition = True
            # print("from if condition")
        # target_seq = np.zeros((1,1))
        target_seq[0, 0] = sample_word_index
        # print(target_seq)
        state_values_encoder = [decoder_h, decoder_c]
    return decoder_sentance

# %% [markdown]
# =============================================================================================================

# %%
X_test = X_test.reset_index(drop=True)

# %%
y_test = y_test.reset_index(drop=True)

# %%
X_train
# Out:
# 43                  what if my food packaging is damaged
# 208              my food arrived damaged i want a refund
# 108    can i order from different restaurants at the ...
# 9        what if my food is delayed but arrives properly
# 171    food arrived cold and squashed can i get a refund
#                              ...
# 63                                  my food arrived cold
# 70                     can i change the delivery address
# 81                    can i request contactless delivery
# 11                      actually the food is not spoiled
# 95              what if i dont get a confirmation email
# Name: Question, Length: 153, dtype: object

# %%
X_test
# Out:
# 0                 how do i know if a restaurant is open
# 1     food arrived cold and squashed can i get a refund
# 2                  what if i forgot my account password
# 3     my order was leaking when delivered refund needed
# 4                    can i report food packaging damage
#                             ...
# 61          how do i cancel an order i havent received
# 62                          how can i delete my account
# 63                 do i need to return the spoiled food
# 64      i want to know if my order has been shipped yet
# 65                     i need help with my recent order
# Name: Question, Length: 66, dtype: object

# %%
# Check if the tokenizer is correctly loaded
print(tokenizer_target.word_index)

# Check if the reverse mapping is correct
print(reverse_word_map_target)
# Out:
# {'start': 1, 'end': 2, 'the': 3, 'refund': 4, 'for': 5, 'is': 6, 'your': 7, 'sorry': 8, 'order': 9, 'we': 10, 'be': 11, 'you': 12, 'we’ll': 13, 'processed': 14, 'a': 15, 'or': 16, 'will': 17, 'can': 18, 'yes': 19, 'apologies': 20, 'in': 21, 'being': 22, 'app': 23, 'issue': 24, 'now': 25, 'contact': 26, 'before': 27, 'an': 28, 'support': 29, 'approved': 30, 'image': 31, 'and': 32, 'initiate': 33, 'this': 34, 'to': 35, 'check': 36, 'request': 37, 'trouble': 38, 'our': 39, 'on': 40, 'way': 41, 'it': 42, 'understand': 43, 'issued': 44, 'shortly': 45, 'inconvenience': 46, 'checkout': 47, 'regret': 48, 'soon': 49, 'we’re': 50, 'experience': 51, 'process': 52, 'delivery': 53, 'apologize': 54, 'items': 55, 'receive': 56, 'replacement': 57, 'orders': 58, 'canceled': 59, 'preparation': 60, 'use': 61, 'with': 62, 'report': 63, 'food': 64, 'spoiled': 65, 'starts': 66, 'tracking': 67, 'during': 68, 'cancel': 69, 'email': 70, 'immediately': 71, 'full': 72, 'are': 73, 'if': 74, 'allowed': 75, 'tipping': 76, 'available': 77, 'changes': 78, 'upload': 79, 'assistance': 80, 'history': 81, 'that': 82, 'please': 83, 'provide': 84, 'after': 85, 'restaurant': 86, 'welcome': 87, 'have': 88, 'wonderful': 89, 'day': 90, 'prepared': 91, 'confirmation': 92, 'notification': 93, 'that’s': 94, 'unacceptable': 95, 'at': 96, 'ensure': 97, 'valid': 98, 'meets': 99, 'conditions': 100, 'missing': 101, 'once': 102, 'cash': 103, 'address': 104, 'each': 105, 'must': 106, 'placed': 107, 'separately': 108, 'delays': 109, 'unless': 110, 'reorder': 111, 'from': 112, 'could': 113, 'of': 114, 'received': 115, 'website': 116, 'can\x92t': 117, 'feature': 118, 'schedule': 119, 'time': 120, 'menus': 121, 'dietary': 122, 'options': 123, 'youâ\x80\x99re': 124, 'reach': 125, 'out': 126, 'anytime': 127, 'verification': 128, 'add': 129, 'duplicate': 130, 'ordering': 131, 'link': 132, 'updates': 133, 'refunds': 134, 'only': 135, 'not': 136, 'cancellation': 137, 'isn\x92t': 138, 'wrong': 139, 'you\x92ll': 140, 'section': 141, 'dispatch': 142, 'hello': 143, 'i': 144, 'made': 145, 'share': 146, 'change': 147, 'option': 148, 'donâ\x80\x99t': 149, 'i\x92m': 150, 'hear': 151, 'no': 152, 'track': 153, 'using': 154, 'thanks': 155, 'i\x92ll': 156, 'would': 157, 'prefer': 158, 'instead': 159, 'extra': 160, 'added': 161, 'enter': 162, 'code': 163, 'apply': 164, 'discount': 165, 'coupon': 166, 'resolve': 167, 'issues': 168, 'has': 169, 'been': 170, 'within': 171, 'business': 172, 'days': 173, 'account': 174, 'deletion': 175, 'don\x92t': 176, 'restaurant\x92s': 177, 'availability': 178, 'provided': 179, 'delayed': 180, 'verified': 181, 'youâ\x80\x99ll': 182, 'via': 183, 'thank': 184, 'let': 185, 'me': 186, 'through': 187, 'referral': 188, 'damage': 189, 'possible': 190, 'weâ\x80\x99ll': 191, 'investigate': 192, 'another': 193, 'dispatched': 194, 'how': 195, 'assist': 196, 'today': 197, 'inapp': 198, 'it\x92s': 199, 'invoices': 200, 'help': 201, 'number': 202, 'accept': 203, 'online': 204, 'payments': 205, 'instructions': 206, 'chat': 207, 'call': 208, 'supportfoodservicecom': 209, 'edit': 210, 'profile': 211, 'settings': 212, 'happens': 213, 'again': 214, 'offer': 215, 'also': 216, 'us': 217, 'directly': 218, 'forgot': 219, 'password': 220, 'reset': 221, 'cancellations': 222, 'you\x92re': 223, 'feel': 224, 'free': 225, 'need': 226, 'further': 227, 'leave': 228, 'review': 229, 'choose': 230, 'contactless': 231, 'shows': 232, 'isnâ\x80\x99t': 233, 'applicable': 234, 'spam': 235, 'folder': 236}
# {1: 'start', 2: 'end', 3: 'the', 4: 'refund', 5: 'for', 6: 'is', 7: 'your', 8: 'sorry', 9: 'order', 10: 'we', 11: 'be', 12: 'you', 13: 'we’ll', 14: 'processed', 15: 'a', 16: 'or', 17: 'will', 18: 'can', 19: 'yes', 20: 'apologies', 21: 'in', 22: 'being', 23: 'app', 24: 'issue', 25: 'now', 26: 'contact', 27: 'before', 28: 'an', 29: 'support', 30: 'approved', 31: 'image', 32: 'and', 33: 'initiate', 34: 'this', 35: 'to', 36: 'check', 37: 'request', 38: 'trouble', 39: 'our', 40: 'on', 41: 'way', 42: 'it', 43: 'understand', 44: 'issued', 45: 'shortly', 46: 'inconvenience', 47: 'checkout', 48: 'regret', 49: 'soon', 50: 'we’re', 51: 'experience', 52: 'process', 53: 'delivery', 54: 'apologize', 55: 'items', 56: 'receive', 57: 'replacement', 58: 'orders', 59: 'canceled', 60: 'preparation', 61: 'use', 62: 'with', 63: 'report', 64: 'food', 65: 'spoiled', 66: 'starts', 67: 'tracking', 68: 'during', 69: 'cancel', 70: 'email', 71: 'immediately', 72: 'full', 73: 'are', 74: 'if', 75: 'allowed', 76: 'tipping', 77: 'available', 78: 'changes', 79: 'upload', 80: 'assistance', 81: 'history', 82: 'that', 83: 'please', 84: 'provide', 85: 'after', 86: 'restaurant', 87: 'welcome', 88: 'have', 89: 'wonderful', 90: 'day', 91: 'prepared', 92: 'confirmation', 93: 'notification', 94: 'that’s', 95: 'unacceptable', 96: 'at', 97: 'ensure', 98: 'valid', 99: 'meets', 100: 'conditions', 101: 'missing', 102: 'once', 103: 'cash', 104: 'address', 105: 'each', 106: 'must', 107: 'placed', 108: 'separately', 109: 'delays', 110: 'unless', 111: 'reorder', 112: 'from', 113: 'could', 114: 'of', 115: 'received', 116: 'website', 117: 'can\x92t', 118: 'feature', 119: 'schedule', 120: 'time', 121: 'menus', 122: 'dietary', 123: 'options', 124: 'youâ\x80\x99re', 125: 'reach', 126: 'out', 127: 'anytime', 128: 'verification', 129: 'add', 130: 'duplicate', 131: 'ordering', 132: 'link', 133: 'updates', 134: 'refunds', 135: 'only', 136: 'not', 137: 'cancellation', 138: 'isn\x92t', 139: 'wrong', 140: 'you\x92ll', 141: 'section', 142: 'dispatch', 143: 'hello', 144: 'i', 145: 'made', 146: 'share', 147: 'change', 148: 'option', 149: 'donâ\x80\x99t', 150: 'i\x92m', 151: 'hear', 152: 'no', 153: 'track', 154: 'using', 155: 'thanks', 156: 'i\x92ll', 157: 'would', 158: 'prefer', 159: 'instead', 160: 'extra', 161: 'added', 162: 'enter', 163: 'code', 164: 'apply', 165: 'discount', 166: 'coupon', 167: 'resolve', 168: 'issues', 169: 'has', 170: 'been', 171: 'within', 172: 'business', 173: 'days', 174: 'account', 175: 'deletion', 176: 'don\x92t', 177: 'restaurant\x92s', 178: 'availability', 179: 'provided', 180: 'delayed', 181: 'verified', 182: 'youâ\x80\x99ll', 183: 'via', 184: 'thank', 185: 'let', 186: 'me', 187: 'through', 188: 'referral', 189: 'damage', 190: 'possible', 191: 'weâ\x80\x99ll', 192: 'investigate', 193: 'another', 194: 'dispatched', 195: 'how', 196: 'assist', 197: 'today', 198: 'inapp', 199: 'it\x92s', 200: 'invoices', 201: 'help', 202: 'number', 203: 'accept', 204: 'online', 205: 'payments', 206: 'instructions', 207: 'chat', 208: 'call', 209: 'supportfoodservicecom', 210: 'edit', 211: 'profile', 212: 'settings', 213: 'happens', 214: 'again', 215: 'offer', 216: 'also', 217: 'us', 218: 'directly', 219: 'forgot', 220: 'password', 221: 'reset', 222: 'cancellations', 223: 'you\x92re', 224: 'feel', 225: 'free', 226: 'need', 227: 'further', 228: 'leave', 229: 'review', 230: 'choose', 231: 'contactless', 232: 'shows', 233: 'isnâ\x80\x99t', 234: 'applicable', 235: 'spam', 236: 'folder'}

# %% [markdown]
# ============================================================================================

# %%
for i in range(len(X_test)):
    sentance = X_test[i]
    original_target = y_test[i]
    input_seq = tokenizer_input.texts_to_sequences([sentance])
    pad_sequence = pad_sequences(input_seq, maxlen=20, padding='post')
    # print('input_sequence =>',input_seq)
    # print("pad_seq=>",pad_sequence)
    predicted_target = decode_seq(pad_sequence)
    print("Test Question: ", i + 1)
    print("Question: ", sentance)
    print("Original Answer:", original_target[6:-4])
    print("Predicted Answer:", predicted_target[:-4])
    print("==" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Test Question:  1
# Question:  how do i know if a restaurant is open
# Original Answer:  check the restaurants availability in the app
# Predicted Answer:  check the restaurants availability in the app
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Test Question:  2
# Question:  food arrived cold and squashed can i get a refund
# Original Answer:  your refund is approved we’re sorry for the experience
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Test Question:  3
# Question:  what if i forgot my account password
# Original Answer:  use the forgot password option to reset it
# Predicted Answer:  use the forgot password option to reset it
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Test Question:  4
# Question:  my order was leaking when delivered refund needed
# Original Answer:  we apologize your refund is being processed
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Test Question:  5
# Question:  can i report food packaging damage
# Original Answer:  upload an image and request a refund or replacement
# Predicted Answer:  we only accept online payments
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Test Question:  6
# Question:  can i change my order
# Original Answer:  orders can be changed before preparation begins
# Predicted Answer:  hello can can help you with that that you please share your order
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Test Question:  7
# Question:  can i request a specific delivery person
# Original Answer:  no assignments are automated based on availability
# Predicted Answer:  yes choose the contactless option at checkout
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test Question:  8
# Question:  what if my payment fails
# Original Answer:  retry payment or use another method
# Predicted Answer:  hello how can help you with that could you please share your order number
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Test Question:  9
# Question:  thank you how do i get my refund
# Original Answer:  refund initiated amount will be credited within  business days
# Predicted Answer:  check the tracking link or contact support for updates
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  10
# Question:  what if my delivery is late
# Original Answer:  check the tracking link for updates or contact support
# Predicted Answer:  ensure it is valid and meets the conditions
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  11
# Question:  i got spoiled food how do i get my money back
# Original Answer:  we understand your refund will be issued shortly
# Predicted Answer:  we apologize your refund is being processed
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  12
# Question:  there was hair in my food i want a refund
# Original Answer:  we regret the issue refund will be processed soon
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test Question:  13
# Question:  i received stale food need my money back
# Original Answer:  we’ll initiate the refund now sorry for this
# Predicted Answer:  sorry for the issue we’ll process your refund
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Test Question:  14
# Question:  i got spoiled food how do i get my money back
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  we apologize your refund is being processed
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Test Question:  15
# Question:  can i change the delivery time
# Original Answer:  you can change it during checkout before dispatch
# Predicted Answer:  address changes are allowed before dispatch
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  16
# Question:  how do i leave a review for my order
# Original Answer:  you can leave a review in the app after delivery
# Predicted Answer:  leave a review in the app after delivery
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  17
# Question:  there was hair in my food i want a refund
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  18
# Question:  can i change my delivery address after placing the order
# Original Answer:  address changes are allowed before dispatch only
# Predicted Answer:  address changes are allowed before dispatch
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  19
# Question:  the food packaging was torn i want a refund
# Original Answer:  your refund is approved we’re sorry for the experience
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Test Question:  20
# Question:  there was hair in my food i want a refund
# Original Answer:  sorry for the issue we’ll process your refund
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  21
# Question:  my pizza was smashed in transit requesting a refund
# Original Answer:  we apologize your refund is being processed
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test Question:  22
# Question:  my food arrived damaged i want a refund
# Original Answer:  we’ll refund your order sorry for the inconvenience
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test Question:  23
# Question:  can i add special instructions for my order
# Original Answer:  yes you can add instructions at checkout
# Predicted Answer:  extra can be made before the order is prepared
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Test Question:  24
# Question:  my order was leaking when delivered refund needed
# Original Answer:  our apologies refund is on the way
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test Question:  25
# Question:  my pizza was smashed in transit requesting a refund
# Original Answer:  we’ll refund your order sorry for the inconvenience
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  26
# Question:  what if my payment fails
# Original Answer:  retry payment or use another method contact support if needed
# Predicted Answer:  hello how can help you with that could you please share your order number
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test Question:  27
# Question:  i received stale food need my money back
# Original Answer:  we’ll refund your order sorry for the inconvenience
# Predicted Answer:  sorry for the issue we’ll process your refund
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test Question:  28
# Question:  food arrived late and completely ruined i need a refund
# Original Answer:  we regret the issue refund will be processed soon
# Predicted Answer:  we apologize your refund is being processed
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  29
# Question:  food arrived cold and squashed can i get a refund
# Original Answer:  refund is being processed apologies for the trouble
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test Question:  30
# Question:  heres the image of the order i got
# Original Answer:  it looks like the order is incorrect well process a replacement for you
# Predicted Answer:  contact support immediately to resolve delivery issues
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Test Question:  31
# Question:  can i get an invoice for my order
# Original Answer:  yes invoices are available in your order history
# Predicted Answer:  yes invoices are available in the order history section
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Test Question:  32
# Question:  what if i am not home during delivery
# Original Answer:  contact support to reschedule or request doorstep delivery
# Predicted Answer:  thanks ill check it now
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Test Question:  33
# Question:  alright thanks
# Original Answer:  youre welcome let us know for further assistance
# Predicted Answer:  youre welcome feel free to reach out if you need further assistance have a wonderful day
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Test Question:  34
# Question:  food arrived cold and squashed can i get a refund
# Original Answer:  we apologize your refund is being processed
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test Question:  35
# Question:  can i cancel an order before its prepared
# Original Answer:  orders can be canceled before preparation begins
# Predicted Answer:  orders cant be canceled once dispatched
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  36
# Question:  thank you how long will the replacement take
# Original Answer:  the replacement will be delivered within  minutes to an hour
# Predicted Answer:  check the restaurant before ordering
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Test Question:  37
# Question:  can i change items after ordering
# Original Answer:  changes can be made before the order is prepared
# Predicted Answer:  ensure items feel free to reach out if
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test Question:  38
# Question:  what payment methods do you accept
# Original Answer:  we accept credit cards debit cards and digital wallets
# Predicted Answer:  thanks ill check it now
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  39
# Question:  can i cancel my order before it arrives
# Original Answer:  orders can be canceled before preparation starts
# Predicted Answer:  yes you can cancel it would you prefer that instead
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test Question:  40
# Question:  i received stale food need my money back
# Original Answer:  we regret the issue refund will be processed soon
# Predicted Answer:  sorry for the issue we’ll process your refund
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test Question:  41
# Question:  the food is spoiled
# Original Answer:  iâm sorry to hear that please upload an image for verification
# Predicted Answer:  the image shows food is not spoiled refund isnât applicable
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Test Question:  42
# Question:  can i still cancel my order
# Original Answer:  cancellation isnât allowed unless specific issues are present
# Predicted Answer:  hello can can be added before preparation
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Test Question:  43
# Question:  i received stale food need my money back
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  sorry for the issue we’ll process your refund
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  44
# Question:  can i use multiple promo codes
# Original Answer:  only one promo code can be applied per order
# Predicted Answer:  ensure ensure the coupon is valid and meets the conditions
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test Question:  45
# Question:  do you offer discounts for frequent issues
# Original Answer:  we may offer coupons based on issue frequency
# Predicted Answer:  hello i can help you with that could you please share your order number
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Test Question:  46
# Question:  there was hair in my food i want a refund
# Original Answer:  we apologize your refund is being processed
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  47
# Question:  i received stale food need my money back
# Original Answer:  we understand your refund will be issued shortly
# Predicted Answer:  sorry for the issue we’ll process your refund
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Test Question:  48
# Question:  can i order from multiple restaurants at once
# Original Answer:  no each order must be placed separately
# Predicted Answer:  no each order must be placed separately
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Test Question:  49
# Question:  will i get a full refund
# Original Answer:  yes youll receive a full refund if verified
# Predicted Answer:  if it happens check it now
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Test Question:  50
# Question:  do you offer cashondelivery
# Original Answer:  no we currently only accept online payments
# Predicted Answer:  hello how can i assist you today
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Test Question:  51
# Question:  can i request contactless delivery
# Original Answer:  yes choose the contactless delivery option at checkout
# Predicted Answer:  yes choose the contactless option at checkout
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  52
# Question:  my order was leaking when delivered refund needed
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Test Question:  53
# Question:  my food arrived damaged i want a refund
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Test Question:  54
# Question:  the meal was spilled in the package refund please
# Original Answer:  sorry for the issue we’ll process your refund
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test Question:  55
# Question:  there was hair in my food i want a refund
# Original Answer:  refund is being processed apologies for the trouble
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Test Question:  56
# Question:  can i request a replacement instead of a refund if i have issues next time
# Original Answer:  yes replacements are available as an alternative to refunds
# Predicted Answer:  yes you can request refunds or cancellations anytime
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test Question:  57
# Question:  food arrived cold and squashed can i get a refund
# Original Answer:  that’s unacceptable your refund is approved
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Test Question:  58
# Question:  can i order food for pickup
# Original Answer:  we currently offer delivery only no pickup options
# Predicted Answer:  yes provide the delivery address during checkout
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Test Question:  59
# Question:  i got spoiled food how do i get my money back
# Original Answer:  sorry for the issue we’ll process your refund
# Predicted Answer:  we apologize your refund is being processed
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Test Question:  60
# Question:  my order was leaking when delivered refund needed
# Original Answer:  we understand your refund will be issued shortly
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Test Question:  61
# Question:  my order was leaking when delivered refund needed
# Original Answer:  sorry for the issue we’ll process your refund
# Predicted Answer:  we regret the issue refund will be processed soon
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test Question:  62
# Question:  how do i cancel an order i havent received
# Original Answer:  orders can be canceled before dispatch
# Predicted Answer:  orders can be canceled before preparation starts
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Test Question:  63
# Question:  how can i delete my account
# Original Answer:  contact support to request account deletion
# Predicted Answer:  contact support to request account deletion
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Test Question:  64
# Question:  do i need to return the spoiled food
# Original Answer:  no return required discard spoiled food for safety
# Predicted Answer:  contact support to request account issues
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Test Question:  65
# Question:  i want to know if my order has been shipped yet
# Original Answer:  i can check that for you please provide your order id so i can give you an update
# Predicted Answer:  yes you can request a refund for wrong items
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Test Question:  66
# Question:  i need help with my recent order
# Original Answer:  sure what seems to be the issue with your order
# Predicted Answer:  we apologize can you share an image for verification
# ====================================================================================================

# %%
import tensorflow as tf
print(tf.__version__)  # Check on both saving and loading environments
# Out:
# 2.18.0

# %%
# After loading the model
model_loaded.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, None, 256) │     49,920 │ encoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_9         │ (None, None)      │          0 │ encoder_inputs[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, None, 256) │     60,672 │ decoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 256),     │    525,312 │ embedding_2[0][0… │
# │                     │ (None, 256),      │            │ not_equal_9[0][0] │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    525,312 │ embedding_3[0][0… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 237) │     60,909 │ lstm_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,444,252 (9.32 MB)
#  Trainable params: 1,222,125 (4.66 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,222,127 (4.66 MB)

# %%
import h5py

with h5py.File("/content/model_qa.weights.h5", "r") as f:
    if "model_weights" in f:
        print("Layers in weights file:", list(f["model_weights"].keys()))
    else:
        print("Weights file is empty or corrupt!")
# Out:
# Weights file is empty or corrupt!

# %%
import tensorflow as tf
import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.18.0
# Keras version: 3.8.0

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
import os
from tensorflow.keras.models import model_from_json

# Paths
model_json_path = '/content/model_qa.json'
weights_path = '/content/model_qa.weights.h5'

# Step 1: Check if files exist and are valid
def check_file(path):
    if not os.path.exists(path):
        print(f"[ERROR] File not found: {path}")
        return False
    if os.path.getsize(path) == 0:
        print(f"[ERROR] File is empty: {path}")
        return False
    print(f"[OK] File '{path}' is valid ({os.path.getsize(path)} bytes)")
    return True

json_ok = check_file(model_json_path)
weights_ok = check_file(weights_path)

# Step 2: Try loading the model and weights
if json_ok and weights_ok:
    try:
        # Load model architecture
        with open(model_json_path, 'r') as f:
            model_json = f.read()
        model = model_from_json(model_json)
        print(f"[OK] Model architecture loaded from JSON. Number of layers: {len(model.layers)}")

        # Attempt to load weights
        try:
            model.load_weights(weights_path)
            print(f"[MATCH] Weights loaded successfully. Architecture and weights match.")
        except Exception as e:
            print(f"[MISMATCH] Failed to load weights. Architecture and weights DO NOT match.")
            print(f"Reason: {e}")

    except Exception as e:
        print(f"[ERROR] Could not load model architecture: {e}")
# Out:
# [OK] File '/content/model_qa.json' is valid (7627 bytes)
# [OK] File '/content/model_qa.weights.h5' is valid (9812344 bytes)
# [OK] Model architecture loaded from JSON. Number of layers: 7
# [MATCH] Weights loaded successfully. Architecture and weights match.
